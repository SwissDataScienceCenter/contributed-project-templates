# %% [markdown]
# # Import database

# %%
import os
os.environ['AIIDA_PATH']= '/work/mc-import/repo'
# !verdi archive import "{{ archive_url }}"

# %% [markdown]
# # Query database

# %%
# imports + load default profile
from aiida import orm, load_profile
load_profile()

# %%
# start querying the database
qb = orm.QueryBuilder()
qb.append(orm.Node)
qb.count()
